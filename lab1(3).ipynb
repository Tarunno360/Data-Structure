# %%
sequence=[10,20,30,40,50,60]
beats = [1,0,0,1,0,1]
temp= sequence[len(sequence)-1]
for i in beats:
  if i==1:

#Function Call:
print(playRight(sequence,beats))

# %%
def helperdiscard(arr, idx):
  for i in range (idx, len(arr) -1):
    arr[i]= arr[i+1]
    arr[len (arr)-1]=0
def discardCards (cards , number)
TO DO
  while i < len(cards):
    if cards (i) == number:
      helperdiscard(cards,i)
      i=-1
    else:
      i+=1
  for j in range (len (cards) )
    if cards[i] == 0:
      cards [1]=0

# %%
a1= [10,2,2,1,3]
a2= a1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-d726ff9af5be> in <cell line: 3>()
#       1 a1= [10,2,2,1,3]
#       2 a2= a1[2]
# ----> 3 print(len(a2))
#
# TypeError: object of type 'int' has no len()

# %%
def helperdiscard(arr, idx):
    for i in range (idx, len(arr) -1):
      arr[i]= arr[i+1]
    arr[len (arr)-1]=0
    return arr
def discardCards (cards , number):
    i=0
    while i < len(cards):
      if cards [i] == number:
        helperdiscard(cards,i)
        i-=1
      else:
        i+=1
    for i in range (len (cards) ):
      if cards[i] == 0:
        cards [i]=None
    return cards

# %%
def evenchecker(x1):
    if x1%2==0:
      return True
    else:
      return False
def waveYourFlag(arr):
  new=[0]*len(arr)
  if evenchecker(arr[0])==True:
    even=0
    odd=1
    for i in range(len(arr)):
      if evenchecker(arr[i])==True:
        new[even]=arr[i]
        even+=2
      else:
        new[odd]=arr[i]
        odd+=2
  else:
    odd=0
    even=1
    for i in range(len(arr)):
      if evenchecker(arr[i])==False:
        new[odd]=arr[i]
        odd+=2
      else:
        new[even]=arr[i]
        even+=2
  return new
print(waveYourFlag([1,3,2,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
from numpy import mean
from IPython.core.display import Math
from typing import IO
import numpy as np

def meancalcu(arr):
  sum=0
  mean=0
  for i in arr:
    sum+=i
  mean=sum/len(arr)
  return mean
print(meancalcu([1,2,3,4,5]))
def sdcalcu(arr):
  count1=0
  sd=0
  N1=len(arr)-1
  mean=meancalcu(arr)
  for i in arr:
    count1=count1+(i-mean)**2
  sd=np.sqrt(count1/N1)
  return sd
print(sdcalcu([10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]))
def newarr(arr):
  diff_count= sdcalcu(arr)*1.5
  count1=0
  for i in arr:
    if abs(i-(meancalcu(arr)))>=diff_count:
      count1+=1
  new=[0]*count1
  count2=0
  for i in range(len(arr)):
    if abs(arr[i]-meancalcu(arr))>=diff_count:
      new[count2]=arr[i]
      count2+=1
  return new
print(newarr([10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]))
# Out:
# 3.0
# 7.960127911260996
# [25, -5]

# %%
def zigzag_walk(floor):
    if not floor or not floor[0]:
        return floor

    m, n = len(floor), len(floor[0])
    row, col = 0, 0
    direction = 1  # 1 for moving right, -1 for moving left

    while row < m:
        if floor[row][col] == 'W':
            print(floor[row][col], end=' ')
        
        if direction == 1:
            if col == n - 1:
                row += 1
                direction = -1
            else:
                col += 1
        else:
            if col == 0:
                row += 1
                direction = 1
            else:
                col -= 1

# Example usage:
floor = [['3W', '8B', '4W', '6B', '1W', '5B'],
         ['3B', '2W', '1B', '6W', '3B', '8W'],
         ['9W', '0B', '7W', '5B', '3W', '8B'],
         ['2B', '1W', '3B', '6W', '0B', '4W'],
         ['1W', '4B', '2W', '8B', '6W', '6B']]

print(zigzag_walk(floor))
# Out:
# None

# %%
def zigzag_walk(floor):
    if not floor or not floor[0]:
        return

    m, n = len(floor), len(floor[0])
    row, col = 0, 0
    direction = 1  # 1 for moving right, -1 for moving left

    while row < m:
        if floor[row][col][-1] == 'W':
            print(floor[row][col], end=' ')
        
        if direction == 1:
            if col == n - 1:
                row += 1
                direction = -1
            else:
                col += 1
        else:
            if col == 0:
                row += 1
                direction = 1
            else:
                col -= 1

# Example usage:
floor = [[3, 'W', 8, 'B', 4, 'W', 6, 'B', 1, 'W', 5, 'B'],
         [3, 'B', 2, 'W', 1, 'B', 6, 'W', 3, 'B', 8, 'W'],
         [9, 'W', 0, 'B', 7, 'W', 5, 'B', 3, 'W', 8, 'B'],
         [2, 'B', 1, 'W', 3, 'B', 6, 'W', 0, 'B', 4, 'W'],
         [1, 'W', 4, 'B', 2, 'W', 8, 'B', 6, 'W', 6, 'B']]

zigzag_walk(floor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4c604cc019f0> in <cell line: 33>()
#      31          [1, 'W', 4, 'B', 2, 'W', 8, 'B', 6, 'W', 6, 'B']]
#      32
# ---> 33 zigzag_walk(floor)
#
# <ipython-input-7-4c604cc019f0> in zigzag_walk(floor)
#       8
#       9     while row < m:
# ---> 10         if floor[row][col][-1] == 'W':
#      11             print(floor[row][col], end=' ')
#      12
#
# TypeError: 'int' object is not subscriptable

# %%
def walk_zigzag():
  row,column=floor.shape
  for i in range(row):
    if i%2==0:
      for j in range(column):
        if 'W'in floor[i][j]:
          print(floor[i][j],end=' ')
      print()
    else:
      for j in range(column-1,-1,-1):
        if 'W' in floor[i][j]:
          print(floor[i][j],end=' ')
floor = [[3, 'W', 8, 'B', 4, 'W', 6, 'B', 1, 'W', 5, 'B'],
         [3, 'B', 2, 'W', 1, 'B', 6, 'W', 3, 'B', 8, 'W'],
         [9, 'W', 0, 'B', 7, 'W', 5, 'B', 3, 'W', 8, 'B'],
         [2, 'B', 1, 'W', 3, 'B', 6, 'W', 0, 'B', 4, 'W'],
         [1, 'W', 4, 'B', 2, 'W', 8, 'B', 6, 'W', 6, 'B']]
walk_zigzag(floor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a26178b3c970> in <cell line: 18>()
#      16          [2, 'B', 1, 'W', 3, 'B', 6, 'W', 0, 'B', 4, 'W'],
#      17          [1, 'W', 4, 'B', 2, 'W', 8, 'B', 6, 'W', 6, 'B']]
# ---> 18 walk_zigzag(floor)
#
# TypeError: walk_zigzag() takes 0 positional arguments but 1 was given

# %%
new_arr=np.zeros((3,4),dtype=int)
